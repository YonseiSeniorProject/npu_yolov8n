# %%
import sys
sys.path.append("../")

import torch
from npu_yolov8n.utils import visualize_multiple_tensors, visualize_multiple_quantized_tensors

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
checkpoint_path = '../checkpoints/qat_fixed.pt' 
saved_model = torch.load(checkpoint_path, device, weights_only=False)

# %%
saved_model.keys()

# %%
state_dict = saved_model['model_state_dict']

# %%
visualize_multiple_quantized_tensors(state_dict, exclude_zeros=True)
